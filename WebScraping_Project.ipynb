# %% [markdown]
# # Web Scraping Job Vacancies - Web Scraping Data Analysis Case Study

# %% [markdown]
# ## Introduction
#
# In this project, we'll build a web scraper to extract job listings from a popular job search platform. We'll extract job titles, companies, locations, job descriptions, and other relevant information.
#
# Here are the main steps we'll follow in this project:
#
# 1. Setup our development environment
# 2. Understand the basics of web scraping
# 3. Analyze the website structure of our job search platform
# 4. Write the Python code to extract job data from our job search platform
# 5. Save the data to a CSV file
# 6. Test our web scraper and refine our code as needed
#
# ## Prerequisites
#
# Before starting this project, you should have some basic knowledge of Python programming and HTML structure. In addition, you may want to use the following packages in your Python environment:
#
# - requests
# - BeautifulSoup
# - csv
# - datetime
#
# These packages should already be installed in Coursera's Jupyter Notebook environment, however if you'd like to install additional packages that are not included in this environment or are working off platform you can install additional packages using `!pip install packagename` within a notebook cell such as:
#
# - `!pip install requests`
# - `!pip install BeautifulSoup`

# %% [markdown]
# ## Step 1: Importing Required Libraries

# %% [markdown]
# ## Step 2: Understand the basics of web scraping
# Scraping job listings can be a valuable way to gather data for analysis, but it's essential to consider the legal and ethical implications, as well as the terms of service of the websites you intend to scrape. Many popular job search platforms have terms of service that prohibit or restrict web scraping. For instance, platforms like Indeed, LinkedIn, and Glassdoor have been known to enforce anti-scraping measures and have taken legal action against unauthorized data extraction. It's crucial to review each platform's terms of service to understand their specific policies regarding data extraction. For this reason, I will be searching for an open data platform where I can get a dataset useful for my project needs.

# %% [markdown]
# ## Step 3: Find Open Data Platforms
# As I mentioned in the Step 2, identifying companies that explicitly permit web scraping can be challenging, as many organizations have policies that restrict automated data extraction. However, some platforms are more lenient or even encourage data extraction through APIs or open data initiatives. I choose the European Union Open Data Portal (EUODP) to extract job listings from. The European Union Open Data Portal provides structured datasets that can be used for analysis, making it a legal and ethical source for job data. Let's do it!

# %% [markdown]
# ## Method 1 (Warm-Up): Download or Access the dataset via API
# I will try the analysis using multiple methods. As Method 1 I will download the dataset and then load it using Pandas. We can think of this method as a warm up step before an actual webscraping data analysis.
#
# For the Method 2, I will try to actually scraping the same dataset from the EUODP.
#
# The dataset I am going to use is "Open job vacancies by Infrabel". I am going to download the .csv file (CSV uses semicolon (;) as a separator.).

# %% [markdown]
# ## Step 4: Data Preparation - Load the data into Python

# %%
# Use pandas to load and inspect the dataset
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
file_path = 'D:/Courses_for_development/Portfolio_DataAnalysis_projects/WebScraping_DataAnalysisProject_Coursera/joblistinfrabel.csv' 
job_list = pd.read_csv(file_path, sep = ';')
# preview the first few rows
job_list.head()
# Out:
#                                        Job title  FR  \
# 0  Stage - Agent de l'usinage spécialisé - Second...
# 1  Stage - Technicien.ne Bâtiments et Ouvrages d'...
# 2                                                NaN
# 3                                                NaN
# 4     Stage - Analyse Software Requirements - Master
#
#                                         Job title NL  Job Id Language role  \
# 0                                                NaN   12282            FR
# 1                                                NaN   19323            FR
# 2        Stage - Technieker Spoorwerken - Middelbaar   24803            NL
# 3  Stage - Roestvorming sporen - Middelbaar/Gradu...   27033            NL
# 4     Stage - Analyse Software Requirements - Master   27850         FR/NL
#
#        Type   Type.1   Type.2  \
# 0  Étudiant  Student  Student
# 1  Étudiant  Student  Student
# 2  Étudiant  Student  Student
# 3  Étudiant  Student  Student
# 4  Étudiant  Student  Student
#
#                                                Apply Publication date Address  \
# 0  https://career2.successfactors.eu/sfcareer/job...       2023-09-03     NaN
# 1  https://career2.successfactors.eu/sfcareer/job...       2022-03-09     NaN
# 2  https://career2.successfactors.eu/sfcareer/job...       2024-08-25     NaN
# 3  https://career2.successfactors.eu/sfcareer/job...       2024-07-18     NaN
# 4  https://career2.successfactors.eu/sfcareer/job...       2025-01-06     NaN
#
#    Postal code             Municipality  \
# 0         7160  Chapelle-Lez-Herlaimont
# 1         7000                     Mons
# 2         1500                    Halle
# 3         8000                   Brugge
# 4         1000                Bruxelles
#
#                                            Geo Shape  \
# 0  {"coordinates": [[[4.282609610000065, 50.45161...
# 1  {"coordinates": [[[3.927831612000034, 50.45177...
# 2  {"coordinates": [[[4.307960834000028, 50.70021...
# 3  {"coordinates": [[[3.17317964700004, 51.226111...
# 4  {"coordinates": [[[4.357185980000054, 50.86031...
#
#                                  Geo Punt Street name Number Street suffix  \
# 0   50.471307819925876, 4.282857249459756         NaN    NaN           NaN
# 1  50.456203480863934, 3.9685021666591336         NaN    NaN           NaN
# 2    50.73071382505011, 4.240277878728712         NaN    NaN           NaN
# 3  51.232646001171425, 3.2071828570336303         NaN    NaN           NaN
# 4   50.853812373745676, 4.369278654960959         NaN    NaN           NaN
#
#    street_name_with_number           Province
# 0                      NaN            Hainaut
# 1                      NaN            Hainaut
# 2                      NaN     Vlaams-brabant
# 3                      NaN    West-Vlaanderen
# 4                      NaN  Bruxelles-Brussel

# %% [markdown]
# ## Step 5: Data Cleaning - Clean & Process the Data
# What does the "cleaning data" step contains? It may contain finding anomalies (find unwanted outliers), removing duplicates, standardize column names (fix structural errors), finding missing data, filtering the information needed, etc.

# %% [markdown]
# ## List column names and Null values
# To clean the dataset I wanted to first know how much null value we have for each column. So, I listed columns and summed up nulls in each column.

# %%
# list(job_list.columns) # listing column names 
# column = ['Job title  FR','Job title NL','Job Id','Language role','Type','Type.1','Type.2','Apply','Publication date','Address','Postal code','Municipality','Geo Shape','Geo Punt','Street name','Number','Street suffix',' street_name_with_number','Province']
# list(job_list.isnull().sum()) # list the number of null values for each column, without column names.
# len(job_list) # gives the number of rows
job_list.isnull().sum() # adding up all null values in each column
# Out:
# Job title  FR               121
# Job title NL                 35
# Job Id                        0
# Language role                 0
# Type                          0
# Type.1                        0
# Type.2                        0
# Apply                         0
# Publication date              0
# Address                     147
# Postal code                   0
# Municipality                  0
# Geo Shape                     0
# Geo Punt                      0
# Street name                 147
# Number                      147
# Street suffix               147
#  street_name_with_number    147
# Province                      0
# dtype: int64

# %% [markdown]
# ##### Challange that I faced:
# While checking for null values in each row, I noticed that the column name "Job title   FR" had an extra space between "title" and "FR." This wasn’t immediately visible, but it caused issues during the analysis. When I tried to check for missing values in this column only, I kept running into an error without understanding why.
# At first glance, this might seem like a minor typo, but small formatting inconsistencies like this can be frustrating and time-consuming to debug, especially after working on a project all day when exhaustion kicks in.
#
# Now, it's time to fix the issue by removing the extra space. I’ll also make formatting adjustments to other columns to ensure consistency and readibility.

# %%
#job_list.columns = job_list.columns.str.replace(' ', '')
#job_list.columns
#list(job_list.columns)
#df.columns = df.columns.str.replace(' ', '') 
new_job_list = job_list.rename({'JobtitleFR': 'JobTitleFR', 'JobtitleNL': 'JobTitleNL', 
                                'JobId': 'Job ID', 'Languagerole': 'Language Role',
                                'Type.1': 'Type 1', 'Type.2': 'Type 2',
                                'Publicationdate': 'PublicationDate', 'Streetname': 'StreetName',
                                'Streetsuffix': 'StreetSuffix',
                                'street_name_with_number': 'StreetNameWithNumber'}, axis=1)
new_job_list
# Out:
#                                             JobTitleFR  \
# 0    Stage - Agent de l'usinage spécialisé - Second...
# 1    Stage - Technicien.ne Bâtiments et Ouvrages d'...
# 2                                                  NaN
# 3                                                  NaN
# 4       Stage - Analyse Software Requirements - Master
# ..                                                 ...
# 188                             Team Lead buying Teams
# 189                                     Company Lawyer
# 190                Realtime Analyst - Central Dispatch
# 191                Realtime Analyst - Central Dispatch
# 192                          Procurement Administrator
#
#                                             JobTitleNL  Job ID Language Role  \
# 0                                                  NaN   12282            FR
# 1                                                  NaN   19323            FR
# 2          Stage - Technieker Spoorwerken - Middelbaar   24803            NL
# 3    Stage - Roestvorming sporen - Middelbaar/Gradu...   27033            NL
# 4       Stage - Analyse Software Requirements - Master   27850         FR/NL
# ..                                                 ...     ...           ...
# 188                             Team Lead buying Teams   32799         FR/NL
# 189                                                NaN   32845            FR
# 190                                                NaN   32928            FR
# 191                                                NaN   32928            FR
# 192                                                NaN   33005            FR
#
#                                        Type  \
# 0                                  Étudiant
# 1                                  Étudiant
# 2                                  Étudiant
# 3                                  Étudiant
# 4                                  Étudiant
# ..                                      ...
# 188  Supply chain, Logistique & Procurement
# 189                         Finance & Legal
# 190            Sécurité & Gestion du Trafic
# 191            Sécurité & Gestion du Trafic
# 192  Supply chain, Logistique & Procurement
#
#                                     Type 1  \
# 0                                  Student
# 1                                  Student
# 2                                  Student
# 3                                  Student
# 4                                  Student
# ..                                     ...
# 188  Supply chain, Logistiek & Procurement
# 189                        Finance & Legal
# 190        Veiligheid & Traffic Management
# 191        Veiligheid & Traffic Management
# 192  Supply chain, Logistiek & Procurement
#
#                                      Type 2  \
# 0                                   Student
# 1                                   Student
# 2                                   Student
# 3                                   Student
# 4                                   Student
# ..                                      ...
# 188  Supply chain, Logistionk & Procurement
# 189                         Finance & Legal
# 190             Safety & Traffic Management
# 191             Safety & Traffic Management
# 192  Supply chain, Logistionk & Procurement
#
#                                                  Apply PublicationDate  \
# 0    https://career2.successfactors.eu/sfcareer/job...      2023-09-03
# 1    https://career2.successfactors.eu/sfcareer/job...      2022-03-09
# 2    https://career2.successfactors.eu/sfcareer/job...      2024-08-25
# 3    https://career2.successfactors.eu/sfcareer/job...      2024-07-18
# 4    https://career2.successfactors.eu/sfcareer/job...      2025-01-06
# ..                                                 ...             ...
# 188  https://career2.successfactors.eu/sfcareer/job...      2024-12-18
# 189  https://career2.successfactors.eu/sfcareer/job...      2025-01-16
# 190  https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 191  https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 192  https://career2.successfactors.eu/sfcareer/job...      2025-02-03
#
#                                         Address  Postalcode  \
# 0                                           NaN        7160
# 1                                           NaN        7000
# 2                                           NaN        1500
# 3                                           NaN        8000
# 4                                           NaN        1000
# ..                                          ...         ...
# 188            RUE DE FRANCE 85 1060A BRUXELLES        1060
# 189  PLACE MARCEL BROODTHAERS 2 1060A BRUXELLES        1060
# 190                                         NaN        1000
# 191                                         NaN        1000
# 192  PLACE MARCEL BROODTHAERS 2 1060A BRUXELLES        1060
#
#                 Municipality  \
# 0    Chapelle-Lez-Herlaimont
# 1                       Mons
# 2                      Halle
# 3                     Brugge
# 4                  Bruxelles
# ..                       ...
# 188             Saint-Gilles
# 189             Saint-Gilles
# 190                Bruxelles
# 191                Bruxelles
# 192             Saint-Gilles
#
#                                               GeoShape  \
# 0    {"coordinates": [[[4.282609610000065, 50.45161...
# 1    {"coordinates": [[[3.927831612000034, 50.45177...
# 2    {"coordinates": [[[4.307960834000028, 50.70021...
# 3    {"coordinates": [[[3.17317964700004, 51.226111...
# 4    {"coordinates": [[[4.357185980000054, 50.86031...
# ..                                                 ...
# 188  {"coordinates": [[[[4.356308510000076, 50.8347...
# 189  {"coordinates": [[[[4.356308510000076, 50.8347...
# 190  {"coordinates": [[[[4.368122588000062, 50.8148...
# 191  {"coordinates": [[[4.360463225000046, 50.90117...
# 192  {"coordinates": [[[[4.356308510000076, 50.8347...
#
#                                     GeoPunt                StreetName Number  \
# 0     50.471307819925876, 4.282857249459756                       NaN    NaN
# 1    50.456203480863934, 3.9685021666591336                       NaN    NaN
# 2      50.73071382505011, 4.240277878728712                       NaN    NaN
# 3    51.232646001171425, 3.2071828570336303                       NaN    NaN
# 4     50.853812373745676, 4.369278654960959                       NaN    NaN
# ..                                      ...                       ...    ...
# 188                   50.8349603, 4.3326534             RUE DE FRANCE     85
# 189                   50.8354886, 4.3382346  PLACE MARCEL BROODTHAERS      2
# 190   50.822325604082216, 4.377065860435226                       NaN    NaN
# 191    50.87298266192055, 4.375234148039785                       NaN    NaN
# 192                   50.8354886, 4.3382346  PLACE MARCEL BROODTHAERS      2
#
#     StreetSuffix        StreetNameWithNumber           Province
# 0            NaN                         NaN            Hainaut
# 1            NaN                         NaN            Hainaut
# 2            NaN                         NaN     Vlaams-brabant
# 3            NaN                         NaN    West-Vlaanderen
# 4            NaN                         NaN  Bruxelles-Brussel
# ..           ...                         ...                ...
# 188            A            85 RUE DE FRANCE  Bruxelles-Brussel
# 189            A  2 PLACE MARCEL BROODTHAERS  Bruxelles-Brussel
# 190          NaN                         NaN  Bruxelles-Brussel
# 191          NaN                         NaN  Bruxelles-Brussel
# 192            A  2 PLACE MARCEL BROODTHAERS  Bruxelles-Brussel
#
# [193 rows x 19 columns]

# %% [markdown]
# ## Filter job listing for Bruxelles only

# %%
jobsinb = new_job_list.loc[job_list['Municipality'] == 'Bruxelles'] # access only the rows that have a specific data. Focus on a specific rows.
len(jobsinb)
#jobsinb
# Out:
# 27

# %% [markdown]
# ## Handling Missing Values: Detect & Remove NaN values
# ##### Idea:
# In Pandas, missing values are represented by None or NaN, which can occur due to uncollected data or incomplete entries. To identify and handle the missing values, Pandas provides two useful functions: isnull() and notnull(). These functions help detect whether a value is NaN or not, making it easier to clean and preprocess data in a DataFrame.
#
# ##### Application:
# I want to remove null values for Job titles first, because later I will check what is the most in-demand job (title) in Bruxelles. First I need to detect rows with missing values or nulls for Bruxelles.
#
# ##### Observations:
# number of total null values in column "Job title NL" for the whole dataset is 35. But if we restrict ourselves only to the Municipality Bruxelles (which is rather smaller dataset), the number of nulls drops to 9 which is plausable.
#
# Now, what remains is to drop those rows with nulls and do the analysis of jobs considering the corresponding column.
#
# ##### Observations:
# num. of rows for Bruxelles was 27, after dropping 9-null job titles, we should remain 18 rows in total (which is the case, check Removing NaNs section below).

# %% [markdown]
# ## Detecting NaNs
# ### Filtering Data Based on Missing Values
#
# In this case, the isnull() function is applied to the “Job title NL” column to filter and display rows with missing job title information in NL.
#
# Question: The filtering did not work for the "Job title FR" column for some reason.

# %%
#pd.isna(job_list['Job title NL'])
# jobsinb[jobsinb.loc[ :,['Job title NL', 'Job title FR']].isnull().sum(axis=1)==2]

null_job_titles = jobsinb[jobsinb['JobTitleNL'].isnull()]
#len(null_job_titles)
null_job_titles.head()
# Out:
#                                            JobTitleFR JobTitleNL  Job ID  \
# 5    Bachelier.ere Technicien.ne Electromécanicien.ne        NaN   30284
# 37                 Technicien.ne Electromécanicien.ne        NaN   30297
# 70   Bachelier.ere Technicien.ne Electromécanicien.ne        NaN   30284
# 115               Realtime Analyst - Central Dispatch        NaN   32928
# 124  Bachelier.ere Technicien.ne Electromécanicien.ne        NaN   30284
#
#     Language Role                          Type  \
# 5              FR                    Technicien
# 37             FR                    Technicien
# 70             FR                    Technicien
# 115            FR  Sécurité & Gestion du Trafic
# 124            FR                    Technicien
#
#                               Type 1                       Type 2  \
# 5                         Technieker                   Technician
# 37                        Technieker                   Technician
# 70                        Technieker                   Technician
# 115  Veiligheid & Traffic Management  Safety & Traffic Management
# 124                       Technieker                   Technician
#
#                                                  Apply PublicationDate  \
# 5    https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 37   https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 70   https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 115  https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 124  https://career2.successfactors.eu/sfcareer/job...      2024-07-17
#
#     Address  Postalcode Municipality  \
# 5       NaN        1000    Bruxelles
# 37      NaN        1000    Bruxelles
# 70      NaN        1000    Bruxelles
# 115     NaN        1000    Bruxelles
# 124     NaN        1000    Bruxelles
#
#                                               GeoShape  \
# 5    {"coordinates": [[[4.357185980000054, 50.86031...
# 37   {"coordinates": [[[4.357185980000054, 50.86031...
# 70   {"coordinates": [[[4.360463225000046, 50.90117...
# 115  {"coordinates": [[[4.357185980000054, 50.86031...
# 124  {"coordinates": [[[[4.368122588000062, 50.8148...
#
#                                    GeoPunt StreetName Number StreetSuffix  \
# 5    50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 37   50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 70    50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 115  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 124  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
#
#     StreetNameWithNumber           Province
# 5                    NaN  Bruxelles-Brussel
# 37                   NaN  Bruxelles-Brussel
# 70                   NaN  Bruxelles-Brussel
# 115                  NaN  Bruxelles-Brussel
# 124                  NaN  Bruxelles-Brussel

# %% [markdown]
# ### Removing NaNs
# Dropping missing values explained: https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/
#
# Since we are checking job titles specifically for Bruxelles, the dataset is not huge and contains only 18 rows after dropping nulls.
# Lets see if the dataset will become even smaller by checking if we have duplicates.

# %%
# clean/drop nulls in a specific column
jobs = jobsinb.dropna(subset = ['JobTitleNL'])
jobs.head()
# len (jobs)
# Out:
#                                         JobTitleFR  \
# 4   Stage - Analyse Software Requirements - Master
# 45                                             NaN
# 62                                             NaN
# 63                                             NaN
# 68                                             NaN
#
#                                            JobTitleNL  Job ID Language Role  \
# 4      Stage - Analyse Software Requirements - Master   27850         FR/NL
# 45  Stage - Projectmedewerker Competentiewijzer vo...   31716            NL
# 62                Realtime Analyst - Central Dispatch   32923            NL
# 63                Realtime Analyst - Central Dispatch   32923            NL
# 68                Stage - Elektromechanica - Bachelor   29817            NL
#
#                             Type                           Type 1  \
# 4                       Étudiant                          Student
# 45                      Étudiant                          Student
# 62  Sécurité & Gestion du Trafic  Veiligheid & Traffic Management
# 63  Sécurité & Gestion du Trafic  Veiligheid & Traffic Management
# 68                      Étudiant                          Student
#
#                          Type 2  \
# 4                       Student
# 45                      Student
# 62  Safety & Traffic Management
# 63  Safety & Traffic Management
# 68                      Student
#
#                                                 Apply PublicationDate Address  \
# 4   https://career2.successfactors.eu/sfcareer/job...      2025-01-06     NaN
# 45  https://career2.successfactors.eu/sfcareer/job...      2024-06-21     NaN
# 62  https://career2.successfactors.eu/sfcareer/job...      2025-01-17     NaN
# 63  https://career2.successfactors.eu/sfcareer/job...      2025-01-17     NaN
# 68  https://career2.successfactors.eu/sfcareer/job...      2024-08-25     NaN
#
#     Postalcode Municipality  \
# 4         1000    Bruxelles
# 45        1000    Bruxelles
# 62        1000    Bruxelles
# 63        1000    Bruxelles
# 68        1000    Bruxelles
#
#                                              GeoShape  \
# 4   {"coordinates": [[[4.357185980000054, 50.86031...
# 45  {"coordinates": [[[4.360463225000046, 50.90117...
# 62  {"coordinates": [[[4.357185980000054, 50.86031...
# 63  {"coordinates": [[[[4.368122588000062, 50.8148...
# 68  {"coordinates": [[[[4.368122588000062, 50.8148...
#
#                                   GeoPunt StreetName Number StreetSuffix  \
# 4   50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 45   50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 62  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 63  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 68  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
#
#    StreetNameWithNumber           Province
# 4                   NaN  Bruxelles-Brussel
# 45                  NaN  Bruxelles-Brussel
# 62                  NaN  Bruxelles-Brussel
# 63                  NaN  Bruxelles-Brussel
# 68                  NaN  Bruxelles-Brussel

# %% [markdown]
# ## Checking for duplicates
# Boolean value False, when we apply .duplicated() function, indicates that the corresponding row is no duplicate; It seems like we do not have duplicates, i.e no any repititve row, in this small dataset.

# %%
#This code gives you a data frame indicating if a row has any repetition in the data frame:

# jobs.duplicated()
no_dup = jobs.drop_duplicates()
no_dup
# len(no_dup)
# Out:
#                                          JobTitleFR  \
# 4    Stage - Analyse Software Requirements - Master
# 45                                              NaN
# 62                                              NaN
# 63                                              NaN
# 68                                              NaN
# 85                                              NaN
# 88                                              NaN
# 114                                             NaN
# 120  Stage - Analyse Software Requirements - Master
# 121  Stage - Analyse Software Requirements - Master
# 122                                             NaN
# 123                                             NaN
# 147                                             NaN
# 148                                             NaN
# 155                                             NaN
# 156                                             NaN
# 171                                             NaN
# 172                                             NaN
#
#                                             JobTitleNL  Job ID Language Role  \
# 4       Stage - Analyse Software Requirements - Master   27850         FR/NL
# 45   Stage - Projectmedewerker Competentiewijzer vo...   31716            NL
# 62                 Realtime Analyst - Central Dispatch   32923            NL
# 63                 Realtime Analyst - Central Dispatch   32923            NL
# 68                 Stage - Elektromechanica - Bachelor   29817            NL
# 85                Bachelor Technieker Elektromechanica   30293            NL
# 88                         Technieker Elektromechanica   30295            NL
# 114                Realtime Analyst - Central Dispatch   32923            NL
# 120     Stage - Analyse Software Requirements - Master   27850         FR/NL
# 121     Stage - Analyse Software Requirements - Master   27850         FR/NL
# 122                Stage - Elektromechanica - Bachelor   29817            NL
# 123                Stage - Elektromechanica - Bachelor   29817            NL
# 147               Bachelor Technieker Elektromechanica   30293            NL
# 148               Bachelor Technieker Elektromechanica   30293            NL
# 155                        Technieker Elektromechanica   30295            NL
# 156                        Technieker Elektromechanica   30295            NL
# 171  Stage - Projectmedewerker Competentiewijzer vo...   31716            NL
# 172  Stage - Projectmedewerker Competentiewijzer vo...   31716            NL
#
#                              Type                           Type 1  \
# 4                        Étudiant                          Student
# 45                       Étudiant                          Student
# 62   Sécurité & Gestion du Trafic  Veiligheid & Traffic Management
# 63   Sécurité & Gestion du Trafic  Veiligheid & Traffic Management
# 68                       Étudiant                          Student
# 85                     Technicien                       Technieker
# 88                     Technicien                       Technieker
# 114  Sécurité & Gestion du Trafic  Veiligheid & Traffic Management
# 120                      Étudiant                          Student
# 121                      Étudiant                          Student
# 122                      Étudiant                          Student
# 123                      Étudiant                          Student
# 147                    Technicien                       Technieker
# 148                    Technicien                       Technieker
# 155                    Technicien                       Technieker
# 156                    Technicien                       Technieker
# 171                      Étudiant                          Student
# 172                      Étudiant                          Student
#
#                           Type 2  \
# 4                        Student
# 45                       Student
# 62   Safety & Traffic Management
# 63   Safety & Traffic Management
# 68                       Student
# 85                    Technician
# 88                    Technician
# 114  Safety & Traffic Management
# 120                      Student
# 121                      Student
# 122                      Student
# 123                      Student
# 147                   Technician
# 148                   Technician
# 155                   Technician
# 156                   Technician
# 171                      Student
# 172                      Student
#
#                                                  Apply PublicationDate  \
# 4    https://career2.successfactors.eu/sfcareer/job...      2025-01-06
# 45   https://career2.successfactors.eu/sfcareer/job...      2024-06-21
# 62   https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 63   https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 68   https://career2.successfactors.eu/sfcareer/job...      2024-08-25
# 85   https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 88   https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 114  https://career2.successfactors.eu/sfcareer/job...      2025-01-17
# 120  https://career2.successfactors.eu/sfcareer/job...      2025-01-06
# 121  https://career2.successfactors.eu/sfcareer/job...      2025-01-06
# 122  https://career2.successfactors.eu/sfcareer/job...      2024-08-25
# 123  https://career2.successfactors.eu/sfcareer/job...      2024-08-25
# 147  https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 148  https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 155  https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 156  https://career2.successfactors.eu/sfcareer/job...      2024-07-17
# 171  https://career2.successfactors.eu/sfcareer/job...      2024-06-21
# 172  https://career2.successfactors.eu/sfcareer/job...      2024-06-21
#
#     Address  Postalcode Municipality  \
# 4       NaN        1000    Bruxelles
# 45      NaN        1000    Bruxelles
# 62      NaN        1000    Bruxelles
# 63      NaN        1000    Bruxelles
# 68      NaN        1000    Bruxelles
# 85      NaN        1000    Bruxelles
# 88      NaN        1000    Bruxelles
# 114     NaN        1000    Bruxelles
# 120     NaN        1000    Bruxelles
# 121     NaN        1000    Bruxelles
# 122     NaN        1000    Bruxelles
# 123     NaN        1000    Bruxelles
# 147     NaN        1000    Bruxelles
# 148     NaN        1000    Bruxelles
# 155     NaN        1000    Bruxelles
# 156     NaN        1000    Bruxelles
# 171     NaN        1000    Bruxelles
# 172     NaN        1000    Bruxelles
#
#                                               GeoShape  \
# 4    {"coordinates": [[[4.357185980000054, 50.86031...
# 45   {"coordinates": [[[4.360463225000046, 50.90117...
# 62   {"coordinates": [[[4.357185980000054, 50.86031...
# 63   {"coordinates": [[[[4.368122588000062, 50.8148...
# 68   {"coordinates": [[[[4.368122588000062, 50.8148...
# 85   {"coordinates": [[[[4.368122588000062, 50.8148...
# 88   {"coordinates": [[[4.360463225000046, 50.90117...
# 114  {"coordinates": [[[4.360463225000046, 50.90117...
# 120  {"coordinates": [[[[4.368122588000062, 50.8148...
# 121  {"coordinates": [[[4.360463225000046, 50.90117...
# 122  {"coordinates": [[[4.357185980000054, 50.86031...
# 123  {"coordinates": [[[4.360463225000046, 50.90117...
# 147  {"coordinates": [[[4.357185980000054, 50.86031...
# 148  {"coordinates": [[[4.360463225000046, 50.90117...
# 155  {"coordinates": [[[4.357185980000054, 50.86031...
# 156  {"coordinates": [[[[4.368122588000062, 50.8148...
# 171  {"coordinates": [[[4.357185980000054, 50.86031...
# 172  {"coordinates": [[[[4.368122588000062, 50.8148...
#
#                                    GeoPunt StreetName Number StreetSuffix  \
# 4    50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 45    50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 62   50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 63   50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 68   50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 85   50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 88    50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 114   50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 120  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 121   50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 122  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 123   50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 147  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 148   50.87298266192055, 4.375234148039785        NaN    NaN          NaN
# 155  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 156  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
# 171  50.853812373745676, 4.369278654960959        NaN    NaN          NaN
# 172  50.822325604082216, 4.377065860435226        NaN    NaN          NaN
#
#     StreetNameWithNumber           Province
# 4                    NaN  Bruxelles-Brussel
# 45                   NaN  Bruxelles-Brussel
# 62                   NaN  Bruxelles-Brussel
# 63                   NaN  Bruxelles-Brussel
# 68                   NaN  Bruxelles-Brussel
# 85                   NaN  Bruxelles-Brussel
# 88                   NaN  Bruxelles-Brussel
# 114                  NaN  Bruxelles-Brussel
# 120                  NaN  Bruxelles-Brussel
# 121                  NaN  Bruxelles-Brussel
# 122                  NaN  Bruxelles-Brussel
# 123                  NaN  Bruxelles-Brussel
# 147                  NaN  Bruxelles-Brussel
# 148                  NaN  Bruxelles-Brussel
# 155                  NaN  Bruxelles-Brussel
# 156                  NaN  Bruxelles-Brussel
# 171                  NaN  Bruxelles-Brussel
# 172                  NaN  Bruxelles-Brussel

# %% [markdown]
# ## Results as a single .csv file - Save the processed data
# Now, it is good to export the cleaned data for further use. We will use this csv file for exploratory analysis.

# %%
# results = pd.ExcelWriter('D:/Courses_for_development/Portfolio_DataAnalysis_projects/WebScraping_DataAnalysisProject_Coursera/cleanedJobs.xlsx')

# jobs.to_excel(results, sheet_name = 'Job Title List')
# results.close()
jobs.to_csv("D:/Courses_for_development/Portfolio_DataAnalysis_projects/WebScraping_DataAnalysisProject_Coursera/cleaned_job_listings.csv", index=False)

# %% [markdown]
# ## Step 6: Exploratory Data Analysis (EDA)
# Since I am done with the cleaning process (it didn't take much time as the dataset was not too huge), it is now time to do some analysis with the remaining data.
# This may contain:
# - Identifying most in-demand job titles
# - Finding top hiring companies
# - Analyzing salary trends (if available)
# - Visualizing results with Matplotlib/Seaborn, etc.
#
# The dataset that I chose to use, unfortunately, does not contain company and salary information, so I will skip those steps for now and continue with the other two steps. Analysis of those two will be left for later where I will now choose much better dataset for my project.

# %% [markdown]
# ## Identifying most in-demand jobs
# If we were using SQL for this analysis, we would first Group by job titles, and then sum up those job titles to find the number of them or count, then Sort by DESC.
#
# It should not be too different with Python Pandas either. It turned out Pandas has the groupby() function that could be useful.
#
# #### Pandas groupby() function is a powerful tool used to split a DataFrame into groups based on one or more columns, allowing for efficient data analysis and aggregation. It follows a “split-apply-combine” strategy, where data is divided into groups, a function is applied to each group, and the results are combined into a new DataFrame. For example, if you have a dataset of sales transactions, you can use groupby() to group the data by product category and calculate the total sales for each category.
#
# ##### Observations:
# After applying groupby() and count(), it turned out that each job title appears 3 times in the table which is weird; it looks like there is actually duplicates, e.g., there is 3 same row with job title "Stage - Analyse Software Requirements - Master". Maybe I need to remove duplicates using different method or by chosing different column?
#
# Oh noo..I manually checked the table and decided there is duplicates, but there is actually no duplicates as the function indicates. Because, if we look carefully to the column "Geo Shape", we can see that even though most of the information is the same for the row, the values for that column is different, which makes those rows no duplicates. So, we are good!
#
# Now, we can conclude that in Bruxeles each job title is equally in-demand at different publication dates. Maybe, we can check the difference accordingt to the different dates and see if it differs from the previous result.

# %%
# counting job titles
job_counts = jobs.groupby("JobTitleNL")["Job ID"].count()
job_counts
# Out:
# JobTitleNL
# Bachelor Technieker Elektromechanica                                   3
# Realtime Analyst - Central Dispatch                                    3
# Stage - Analyse Software Requirements - Master                         3
# Stage - Elektromechanica - Bachelor                                    3
# Stage - Projectmedewerker Competentiewijzer voor Opleiders - Master    3
# Technieker Elektromechanica                                            3
# Name: Job ID, dtype: int64

# %% [markdown]
# ### Checking for demand for jobs depending on the dates they are published.
# We find the number of jobs corresponding each date that are sorted in a ascending order, the jobs are not necessarily different.
# E.g., for the date 2024-07-17 the number of job titles is 6, but 3 is "Bachelor Technieker Elektromechanica" and 3 is "Technieker Elektromechanica", so we have two different jobs in total for this date, not all 6 is different.

# %%
# sort values according to the dates
sort_dates = jobs.sort_values(by = "PublicationDate")
# find the number of jobs corresponding each date that are sorted in a ascending order
sort_dates.groupby("PublicationDate")["Job ID"].count()
# Out:
# PublicationDate
# 2024-06-21    3
# 2024-07-17    6
# 2024-08-25    3
# 2025-01-06    3
# 2025-01-17    3
# Name: Job ID, dtype: int64

# %% [markdown]
# ## Visualizing most in-demand job with Matplotlib/Seaborn
# We can use Matplotlib and Seaborn to create effective visualizations. Different methods can be used here too, such as:
# 1. Bar Chart: Most In-Demand Job Titles
# 2. Time Series: Demand Trends Over Time

# %% [markdown]
# ## Bar Chart
# If you have a count of job titles, a bar chart is a good choice. Since we have found the count of jobs, we can try bar chart.
#
# ##### Observations:
# As we can also see from the chart that each job title occurs 3 times for the giving dates in Bruxelles. Then, we can conclude all are equally common jobs titles.

# %%
# Assuming jobs['JobTtleNL'] contains job titles and you already counted occurrences, btw this is equivalent to the one we did above.
job_count = jobs['JobTitleNL'].value_counts()

plt.figure(figsize=(7, 5))
sns.barplot(x=job_counts.values, y=job_counts.index, palette="Blues")
plt.xlabel("Number of Listings", color = "brown")
plt.ylabel("Job Titles", color = "brown")
plt.title("Demand on different Job Titles", color = "brown")
plt.show()

# %% [markdown]
# ## Time Series
# Because I have dates for job postings, I check to see how demand changes over time in Bruxelles.
#
# For the sake of trying new method of visualizing, I will also use time series.
#
# ##### Observations:
# What we see here is what we observed when I checked for the number of jobs for each date above. That is, the number of jobs published on 2024-07-17 is 6, which shows on that very date demand for those jobs was higher compared to other dates. In fact, on other dates jobs share equal demand rate, i.e., demand for the jobs is constant/remains same over the given time period.
#
# Quick reminder: This results are only for Bruxelles as I filtered out other Municipalities in Step 5.

# %%
# Convert date column to datetime if it's not already
# jobs['Publication date'] = pd.to_datetime(jobs['Publication date'])

# Count job postings by date
job_trends = jobs.groupby('PublicationDate').size()
#job_trends

plt.figure(figsize=(12, 5))
sns.lineplot(x=job_trends.index, y=job_trends.values, marker ="o", color="blue")
plt.xlabel("Date", color = "brown")
plt.ylabel("Number of Job Listings", color = "brown")
plt.title("Job Postings Over Time", color = "brown")
plt.show()

# %% [markdown]
# ## Conclusion & Future Work
# Since this was just a "warm-up" before the actual web scraping project, the results weren’t particularly insightful. The data I used was sourced from an open platform rather than a real job search website. Additionally, the dataset lacked crucial details such as company names, salaries, job descriptions, and other relevant information. Because of this, I was limited in my analysis, only being able to examine job demand.
#
# To make this exercise a bit more interesting, I focused on job listings from a single city. However, this further reduced the dataset size. While working with a smaller dataset is a good starting point, it didn’t feel very practical since real-world data is often much larger and more complex. Now, it's time to take on a more meaningful challenge!
#
# For the next step, I plan to work with a dataset that includes all essential job vacancy details. This will make the data analysis more engaging, insightful, and informative. As I progress, I’ll explore additional aspects to analyze and refine my approach accordingly.

# %% [markdown]
# ## Method 2: Actual Web Scraping Challenge
# #### Done with the "warm-up", now we can "work out"!
